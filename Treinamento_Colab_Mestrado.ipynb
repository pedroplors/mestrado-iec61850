# %% [markdown]
# # Treinamento - Diagnóstico de Rede Elétrica (IEC 61850)
# Este notebook foi gerado automaticamente para facilitar o treinamento do seu modelo usando as GPUs do Google Colab.

# %% [markdown]
# ### 1. Clonar o Repositório do GitHub
# Baixa a versão mais recente do código (`diagnostico_rede_eletrica.py`) que foi otimizada pela nossa automação local.

# %%
# !rm -rf mestrado-iec61850
# !git clone https://github.com/pedroplors/mestrado-iec61850.git
import sys
sys.path.append('/content/mestrado-iec61850')

# %% [markdown]
# ### 2. Acessar o Dataset (`DATASET-MESTRADO.zip`)
# Recomendamos que você faça o upload do arquivo zip para o seu **Google Drive**. Assim você não precisa esperar o upload toda vez que abrir o Colab.
#
# Ao rodar a célula abaixo, o Colab vai pedir permissão para acessar seu Drive.

# %%
from google.colab import drive
drive.mount('/content/drive')

# Copiando o dataset do Drive para a máquina virtual do Colab (mais rápido)
# !cp "/content/drive/MyDrive/DATASET-MESTRADO.zip" "/content/"

# Descompactando o dataset
# !unzip -q /content/DATASET-MESTRADO.zip -d /content/dataset_iec61850/

# %% [markdown]
# ### 3. Iniciar o Treinamento na GPU
# A biblioteca detectará automaticamente a presença da GPU e usará as otimizações (Tensor Cores / float32_matmul_precision).

# %%
from diagnostico_rede_eletrica import treinar_rede

# Inicia o treinamento passando o caminho onde os dados foram descompactados
treinar_rede()
